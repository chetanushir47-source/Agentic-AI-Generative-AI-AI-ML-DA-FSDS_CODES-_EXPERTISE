# %%
class duck():
    def swim(self):
        print('i can swim')
    def talk():
        print('i can talk')


class person():
    
    def gym():
       print('i can swim')
    def walk():
        print('i can talk')
A=duck()
B=person()

A.swim()
# Out:
# i can swim

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
a=(5,6,7)
print(type(a))
# Out:
# <class 'tuple'>

# %%
class laptop():
    
    def config():
        print('i7',16)
lap=laptop()

# %%
class laptop ():
    def config():
        print('i7',16)
lap=laptop()
laptop.config()
# Out:
# i7 16

# %%
class laptop():
0    def config():
        print('i7',16)
lap=laptop()
lap.config()
# the importance of self keyword is import in method if you call anny method using object
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       3         print('i7',16)
#       4 lap=laptop()
# ----> 5 lap.config()
#       6 # the importance of self keyword is import in method if you call anny method using object
#
# TypeError: laptop.config() takes 0 positional arguments but 1 was given

# %%
class laptop():
    def config(self):
        print('I7',16)

lap=laptop()
lap.config()
# Out:
# I7 16

# %%
class laptop():
    def config():
        print('i7',16)
lap=laptop()
laptop.config()
# Out:
# i7 16

# %%
class laptop(): 
    def config(self):  
        print('i7', 16) 

lap = laptop()  
lap1 = laptop()

lap.config()
lap1.config()
# Out:
# i7 16
# i7 16

# %%
class computer():
    def config():
        print('i7',14)
a=5.5
print(type(a))


lap=computer()
print(type(lap))
# Out:
# <class 'float'>
# <class '__main__.computer'>

# %%
class computer ():
    def config(self):
        print('i7',16)
lap=computer()
computer.config(lap)
# Out:
# i7 16

# %%
class laptop():
    def config(self):
        print('hello')
lap=laptop()
lap1=laptop()
lap2=laptop()
lap.config()
lap1.config()
lap2.config()
# Out:
# hello
# hello
# hello

# %%
class car():
    def __init__(self):
        self.mil = 10
        self.com = 'bmw'
        
c1 = car()
c2 = car()

print(c1.com, c1.mil)
print(c2.com, c2.mil)

print(id(c1))
print(id(c2))
# Out:
# bmw 10
# bmw 10
# 3148130141248
# 3148131983568

# %%
class duck():
    def swim(self):
        print('i am duck ican swim')
    def speak(self):
          print('hiii')


class dog():
    def swim(self):
        print('i acan swim buddy')
    def speak(self):
        print('hello')
def display(duck):
    duck.swim()
    duck.speak()

d= duck()
f=dog()
display(d)
display(f)
# Out:
# i am duck ican swim
# hiii
# i acan swim buddy
# hello

# %%
class duck():
    def swim(self):
        print('i am duck & i can swim')
    def speaks(self):
        print('quack quack')

class dog():
    def swim(self):
        print('i am dog & i can swim')
    def speaks(self):
        print('woof woof')

class person():
    def speaks(self):
        print('attend more interview to get placed')
        
def display(obj): # we define outside of the class
    obj.swim()
    obj.speaks()
    obj.person()
    
d = duck()
dg = dog()
p = person()

display(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 26
#      23 dg = dog()
#      24 p = person()
# ---> 26 display(p)
#
# Cell In[44], line 18, in display(obj)
#      17 def display(obj): # we define outside of the class
# ---> 18     obj.swim()
#      19     obj.speaks()
#      20     obj.person()
#
# AttributeError: 'person' object has no attribute 'swim'

# %%
class duck:
    def swim(self):
        print('i am duck & i can swim')
    def speaks(self):
        print('quack quack')

class dog:
    def swim(self):
        print('i am dog & i can swim')
    def speaks(self):
        print('woof woof')

class person:
    def speaks(self):
        print('attend more interview to get placed')
    def swim(self):
        print('need to learn for swimming')
         
def display(obj): # we define outside of the class
    obj.swim()
    obj.speaks()
    #obj.person()
    
d = duck()
dg = dog()
p = person()

display(p)
# Out:
# need to learn for swimming
# attend more interview to get placed

# %%
a=5
b='world'
print(a+b)
# we cant ADD a intiger with a string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 3
#       1 a=5
#       2 b='world'
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a,b= 5,6
print(type(a))
print(a+b)
# Out:
# <class 'int'>
# 11

# %%
int.__add__(a,b)
# Out:
# 11

# %%
int.__sub__(a,b)
# Out:
# -1

# %%
int.__mul__(a,b)
# Out:
# 30

# %%
int.__mod__(a,b)
# Out:
# 5

# %%
class student():
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2
        
    def __add__(self, other): ## WE DEFINE THE ADD METHOD . THIS CONCEPT IS CALLED OPERATOR OVERLOADING
        m1 = self.m1 + other.m1
        m2 = self.m2 + other.m2
        s3 = student(m1,m2)
        
        return s3   
 
s1 = student(60,70)
s2 = student(80,90)

s3 = s1 + s2 
# when we create add method in above behind the memory s1 & s2 will convert to self & other respectivly
print(s3.m1)
print(s3.m2)

# if you want to add 2 student then operator need to overload
# Out:
# 140
# 160

# %%
class demo():
    def add(self,a,b):
        return a+b

    def add(self,c,d,e):
        return c+d+e

d= demo()
print(d.add(2,3,4))
# Out:
# 9

# %%
class demo():
    def add(self,a=0,b=0,c=0,d=0,e=0):
        return a+b+c+d+e
    
d=demo()
print(d.add(2,3,4,5,6)  )
# Out:
# 20

# %%
class student():
    def __init__(self,m1,m2):
        self.m1=m1
        self.m2=m2
    def sum(self,a=None,b=None,c=None,d=None,e=None):
        if a!=None and b!=None and c!=None and d!=None and e!=None:
            s=a+b+c+d+e
        elif a!=None and b!=None and c!=None and d!=None :
            s=a+b+c+d
        elif a!=None and b!=None and c!=None :
            s=a+b+c
        elif a!=None and b!=None:
            s=a+b
        else :s= a

        return s
s1= student(80,90)

print(s1.sum(10)) # hear we can pass 1 parameter
print(s1.sum(10,20)) # hear we can pass 2 parameter
print(s1.sum(10,20,30)) # hear we can pass 3 parameter
print(s1.sum(10,30))
print(s1.sum(10,20,30,40))
print(s1.sum(10, 20, 30, 40, 50))

# THIS CONCEPT CALLED AS METHOD OVERLOADING
# Out:
# 10
# 30
# 60
# 40
# 100
# 150

# %% [markdown]
# # method overriding inheritance

# %%
class a:
    def show(self):
        print('in a show')
class b():
    pass 
s=a()
s.show()
# Out:
# in a show

# %%
class a():
    def show(self):
        print('in a show')
class b(a):
    pass

s2= b()
s2.show()
# Out:
# in a show

# %% [markdown]
# # Abstraction

# %%
class computer():
    def processor(self):
        print('running')

# %%
class vehicle:
    def __init__(self):
        self.no_of_types_vehicle = n 
    def start(self): # we just declare but not define that means nothing to do with start method hear
        pass

class bike:
    def __init__(self):
        self.no_of_tyres = 2
    def start(self):
        print('start with kick')
        
class activa:
    def __init__(self):
        self.no_of_tyres = 2
    def start(self):
        print('self start')
        
class car:
    def __init__(self):
        self.no_of_tyres = 4
    def start(self):
        print('start with key')

# %%
from abc import ABC, abstractmethod

class vehicle(ABC):
    def __init__(self,n):
        self.no_of_types_vehicle = n 
    @abstractmethod
    def start(self): # we just declare but not define that means nothing to do with start method hear
        pass

class bike:
    def __init__(self):
        self.no_of_tyres = 2
    def start(self):
        print('start with kick')
        
class activa:
    def __init__(self):
        self.no_of_tyres = 2
    def start(self):
        print('self start')
        
class car:
    def __init__(self):
        self.no_of_tyres = 4
    def start(self):
        print('start with key')

# %%
from abc import ABC, abstractmethod

class vehicle(ABC):
    def __init__(self,n):
        self.no_of_types_vehicle = n 
        
    @abstractmethod
    def start(self): # we just declare but not define that means nothing to do with start method hear
        pass

# %%
from abc import ABC, abstractmethod

class computer(ABC):
    @abstractmethod
    def process(self):
        pass

class Laptop(computer):    #------ Laptop is subclass of computer 
    def process(self):
        print('its working')
        
com1 = Laptop()
#com = computer()
com1.process()
# Out:
# its working
