# %%
import pandas as pd

# %%
movies= pd.read_csv(r"C:\Users\shree\Downloads\Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movies)
# Out:
# 559

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.1.3

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head
# Out:
# <bound method NDFrame.head of                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# ...

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns= ['Film', 'Genre', 'Criticrating','Audiancerating','Buggetmillions', 'Year']

# %%
movies.head(1)
# Out:
#                     Film   Genre  Criticrating  Audiancerating  \
# 0  (500) Days of Summer   Comedy            87              81
#
#    Buggetmillions  Year
# 0               8  2009

# %%
movies.describe()
# Out:
#        Criticrating  Audiancerating  Buggetmillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.describe().transpose()
# Out:
#                 count         mean        std     min     25%     50%     75%  \
# Criticrating    559.0    47.309481  26.413091     0.0    25.0    46.0    70.0
# Audiancerating  559.0    58.744186  16.826887     0.0    47.0    58.0    72.0
# Buggetmillions  559.0    50.236136  48.731817     0.0    20.0    35.0    65.0
# Year            559.0  2009.152057   1.362632  2007.0  2008.0  2009.0  2010.0
#
#                    max
# Criticrating      97.0
# Audiancerating    96.0
# Buggetmillions   300.0
# Year            2011.0

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   Criticrating    559 non-null    int64
#  3   Audiancerating  559 non-null    int64
#  4   Buggetmillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film= movies.Film.astype('category')

# %%
movies.describe()
# Out:
#        Criticrating  Audiancerating  Buggetmillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.Genre= movies.Genre.astype('category')

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   Criticrating    559 non-null    int64
#  3   Audiancerating  559 non-null    int64
#  4   Buggetmillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movies.Year= movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   Criticrating    559 non-null    int64
#  3   Audiancerating  559 non-null    int64
#  4   Buggetmillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j=sns.jointplot(data=movies,x='Criticrating', y= 'Audiancerating')
plt.show()

# %%
j= sns.jointplot( data= movies ,x='Criticrating', y= 'Audiancerating',kind='hex')
plt.show()
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   Criticrating    559 non-null    int64
#  3   Audiancerating  559 non-null    int64
#  4   Buggetmillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
plt.hist(movies.Buggetmillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].Buggetmillions)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  Criticrating  Audiancerating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    Buggetmillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
plt.hist(movies[movies.Genre == 'Action'].Buggetmillions, bins = 20)
plt.hist(movies[movies.Genre == 'Thriller'].Buggetmillions, bins = 20)
plt.hist(movies[movies.Genre == 'Drama'].Buggetmillions, bins = 20)
plt.legend()
plt.show()

# %%
for gen in movies .Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
v1 =sns.lmplot(data=movies, x='Criticrating', y='Audiancerating',fit_reg=False)
plt.show(1)

# %%
j= sns.jointplot(data= movies,x='Criticrating',y='Audiancerating')
plt.show()

# %%
j= sns.jointplot(data=movies, x='Audiancerating',y='Criticrating', kind ='hex')
plt.show(1)

# %%
m1=sns.distplot(movies.Audiancerating)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m2=sns.distplot(movies.Audiancerating,bins=15)
plt.show()

# %%
n1=plt.hist(movies.Audiancerating, bins=15)
plt.show()

# %%
sns.set_style('white')
n1=plt.hist(movies.Audiancerating,bins=15)
plt.show()

# %%
n1= plt.hist(movies.Criticrating,bins=20)
plt.show()

# %%
plt.hist(movies.Buggetmillions)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Drama'].Buggetmillions)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  Criticrating  Audiancerating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    Buggetmillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
plt.hist(movies[movies.Genre=='Action'].Buggetmillions,bins=20)
plt.hist(movies[movies.Genre=='Thriller'].Buggetmillions,bins=20)
plt.hist(movies[movies.Genre=='Drama'].Buggetmillions,bins=20)
plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].Buggetmillions,\
         movies[movies.Genre=='Thriller'].Buggetmillions,\
         movies[movies.Genre=='Drama'].Buggetmillions,\
         movies[movies.Genre=='Comedy'].Buggetmillions],
         bins=20,stacked=True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1=sns.lmplot(data=movies,x='Audiancerating', y='Criticrating',\
                fit_reg=False)
plt.show(1)

# %%
vis1=sns.lmplot(data=movies,x='Audiancerating', y='Criticrating',\
fit_reg=False,hue='Genre')
plt.show()

# %%
vis1=sns.lmplot(data=movies,x='Audiancerating',y ='Criticrating',\
fit_reg=False,hue='Genre',aspect=1)
plt.show()

# %%
k1=sns.kdeplot(movies.Audiancerating)
k2=sns.kdeplot(movies.Criticrating)
plt.show(1)

# %%
k1=sns.kdeplot(movies.Audiancerating)
k2=sns.kdeplot(movies.Criticrating)
plt.show(1)

# %%
k2=sns.kdeplot(movies.Audiancerating)
plt.show(1)

# %%
sns.set_style('dark')
k1=sns.kdeplot(movies.Buggetmillions,shade_lowest=False)
plt.show()

# %%
sns.set_style('dark')
k1=sns.kdeplot(x=movies.Buggetmillions,y=movies.Audiancerating)
plt.show()

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   Criticrating    559 non-null    int64
#  3   Audiancerating  559 non-null    int64
#  4   Buggetmillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
f, ax=plt.subplots(1,2,figsize=(12,6))
plt.show()

# %%
w=sns.boxplot(data=movies, x='Genre', y='Criticrating')
plt.show()

# %%
z=sns.violinplot(data= movies, x='Genre', y='Criticrating')
plt.show()

# %%
w1= sns.boxplot(data=movies[movies.Genre=='Drama'],x='Year',y='Criticrating')
plt.show()

# %%
z=sns.violinplot(data =movies[movies.Genre=='Drama'],x='Year',y='Criticrating')
plt.show()

# %%
g=sns.FacetGrid(movies, row='Genre',col='Year',hue='Genre')
plt.show(1)

# %%
plt.scatter(movies.Criticrating,movies.Audiancerating)
plt.show()

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year', hue='Genre')
g=g.map(plt.scatter,'Criticrating','Audiancerating')
plt.show()

# %%
g=sns.FacetGrid(movies, row='Genre',col='Year',hue='Genre')
g= g.map(plt.hist,'Buggetmillions')
plt.show()

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws=dict(s=50, linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'Criticrating','Audiancerating',**kws)
plt.show()

# %%
sns.set_style('darkgrid')
f, axes=plt.subplots(2,2 ,figsize=(15,15))


k1= sns.kdeplot(
    x=movies.Buggetmillions,
    y=movies.Audiancerating,ax=axes[0,0],
    cmap='viridis')
k2=sns.kdeplot(
    x=movies.Buggetmillions,
    y=movies.Criticrating, ax=axes[0,1],
    cmap='viridis')
k1.set(xlim= (-50,250))
k2.set(xlim= (-50,250))
z=sns.violinplot(data=movies[movies.Genre=='Drama'],
                 x='Year',y='Criticrating' ,ax=axes[1,0],palette='Dark2')
k4=sns.kdeplot(x=movies.Buggetmillions, y=movies.Audiancerating,
               shade=True, shade_lowest=False, cmap='Reds',ax=axes[1,1])
k4b=sns.kdeplot(
    x=movies.Criticrating,
    y=movies.Audiancerating,cmap='Reds',ax=axes[1,1])
plt.show()
