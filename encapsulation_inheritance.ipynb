# %%
class car():
    def __init__(self):
        self.mil=10
        self.com='bmw'

c1=car()
c2=car()

print(c1.com,c1.mil)
print(c2.com,c2.mil)

print(id(c1))
print(id(c2))
# Out:
# bmw 10
# bmw 10
# 2535392873504
# 2535390833360

# %%
class car():
    def __init__(self):
        self.mil=10
        self.com='bmw'
c1=car()
c2=car()

c2.mil= 9
c1.mil= 20
c1.com= 'Maruti'

print(c1.com,c1.mil)
print(c2.com,c2.mil)
# Out:
# Maruti 20
# bmw 9

# %%
class car():
    wheels=5

    def __init__(self):
        self.mil=10
        self.com='bmw'

c1= car()
c2=car()
c2.mil=7

print(c1.mil,c1.com,c1.wheels)
print(c2.mil,c2.com,c2.wheels)
# Out:
# 10 bmw 5
# 7 bmw 5

# %%
class car():
    wheels=5
    def __init__(self):
        self.mil=10
        self.com='bmw'

c1=car()
c2=car()

c2.mil=7
c2.wheels= 4
print(c1.com,c1.mil,c1.wheels)
print(c2.com,c2.mil,c2.wheels)
# Out:
# bmw 10 5
# bmw 7 4

# %%
class student():
    school= 'nit'

    def __init__(self,m1,m2,m3):
        self.m1=m1
        self.m2=m2
        self.m3=m3

    def avg(self):
        return (self.m1+self.m2+self.m3)/3

s1= student(10,20,30)
s2= student(5,13,14)


print(s1.avg())
print(s2.avg())
# Out:
# 20.0
# 10.666666666666666

# %%
class student ():
    school='nit'

    def __init__(self,m1,m2,m3):
        self.m1=m1
        self.m2=m2
        self.m3=m3

    def avg(self):
        return (self.m1+self.m2+self.m3)/3

    def info(cls):
        return cls.school

s1= student(10,20,30)
s2= student(5,10,15)


print(s1.avg())
print(s2.avg())


print(s1.info())
print(s2.info())
# Out:
# 20.0
# 10.0
# nit
# nit

# %%
class student():
    school= 'nit'

    def __init__(self,m1,m2,m3):
        self.m1 =m1
        self.m2=m2
        self.m3=m3

    def avg(self):
        return (self.m1+self.m2+self.m3)/3

    @classmethod
    def getSchool(cls):
        return cls.school

    def info():
        print('this is student class')

s1=student(10,20,30)
s2= student(20,52,52)


print(s1.avg())
print(s2.avg())
print(student.getSchool())
student.info()
# Out:
# 20.0
# 41.333333333333336
# nit
# this is student class

# %%
class a():
    def feature1(self):
        print('feature1')
    def feature2(self):
        print('feature2')
a1=a()

a1.feature1()
a1.feature2()
# Out:
# feature1
# feature2

# %%
class a():
    def feature1(self):
        print('feature1')
    def feature2(self):
        print('feature2')

class b(a):
    def feature3(self):
        print('feature3')
    def feature4(self):
        print('feature4')

class c(b):
    def feature5(self):
        print('fearture5')

        
a1=a()
a2=b()
a3=c()
# Out:
# feature1
# feature2

# %%
class a():
    def __init__(self):
        print('in a init')

    def f1(self):
        print('f1')
    def f2(self):
        print('f2')
class b(a):
    def f3(self):
        print('f3')
    def f4(self):
        print('f4')

a1=a()
a2=b()
    # the init functtion call automatically no
# need to call the init function it is a special method
# Out:
# in a init
# in a init

# %%
class a():
    def __init__(self):
        print('init')
    def f1(self):
        print('f1')

class b(a):
    def __init__(self):
        super().__init__()
        print('init b')
        
    def f2(self):
        print('f2')


b2=b()
        # when we apply super m ethod on our sub class it print the parent class also
# Out:
# init
# init b
